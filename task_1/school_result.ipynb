# %% [markdown]
# # Задание 1
# Построить описательные статистики, ящики с усами и гистограммы распределения в Python

# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
df = pd.read_csv('Nova_Scotia_Assessment_Results_by_Year_and_Board_-_Mathematics_in_Grade_6.csv', sep=",", header = 0, index_col=False)
df.head()
# Out:
#       Year  Grade_Level Assessment  Program Board Sex Adaptation  IPP  \
# 0  2012-13            6          M  English  HRSB   M        NaN  NaN
# 1  2012-13            6          M  English  SRSB   F        NaN  NaN
# 2  2012-13            6          M  English  HRSB   M        NaN  Yes
# 3  2013-14            6          M  English  HRSB   F        NaN  NaN
# 4  2012-13            6          M  English  HRSB   M        NaN  Yes
#
#   Exemption Eligible  Math_Score           Math_Level
# 0       NaN      Yes       539.0              Level 3
# 1       NaN      Yes       556.0              Level 3
# 2       NaN       No         NaN  Did not participate
# 3       NaN      Yes       541.0              Level 3
# 4       NaN       No         NaN  Did not participate

# %%
df.shape
# Out:
# (51624, 12)

# %%
df.dtypes
# Out:
# Year            object
# Grade_Level      int64
# Assessment      object
# Program         object
# Board           object
# Sex             object
# Adaptation      object
# IPP             object
# Exemption       object
# Eligible        object
# Math_Score     float64
# Math_Level      object
# dtype: object

# %%
df.describe()
# Out:
#        Grade_Level    Math_Score
# count      51624.0  47835.000000
# mean           6.0    499.487948
# std            0.0    102.280171
# min            6.0    200.000000
# 25%            6.0    428.000000
# 50%            6.0    500.620000
# 75%            6.0    572.000000
# max            6.0    800.000000

# %% [markdown]
# Распределение похоже на распределение Стьюдента (наблюдаются более высокие хвосты распределения (в отличие от нормального распределения))

# %%
df['Math_Score'].hist(bins=50)
plt.xlabel('Math_score')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['Math_Score'], kde=True)
plt.show()

# %%
df.boxplot(column='Math_Score')
plt.show()

# %%
sns.boxplot(x=df['Math_Score'])
# Out:
# <AxesSubplot:xlabel='Math_Score'>
